# %%
def get_curr_dur():
    import os
    a = os.getcwd()
    return print(f'Current working directory is:{a}')
get_curr_dur()
# Out:
# Current working directory is:/Users/jakepulitzer/GitHub/python-notebooks

# %%
# relativedelta for date relative to today
import pandas as pd
from dateutil.relativedelta import *
from datetime import datetime, timedelta, date

# get todays date
end_date = pd.to_datetime(date.today())
start_date = pd.to_datetime('2020-01-01')
print('Start Date:',start_date,"----->  End Date:",end_date)
# Out:
# Start Date: 2020-01-01 00:00:00 ----->  End Date: 2023-08-15 00:00:00

# %%
# !pip install yfinance --upgrade
# Out:
# Requirement already satisfied: yfinance in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (0.2.28)
# Requirement already satisfied: pandas>=1.3.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.16.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.18.1)
# Requirement already satisfied: requests>=2.31 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: lxml>=4.9.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4>=4.11.1->yfinance) (1.9.5)
# Requirement already satisfied: six>=1.9 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from html5lib>=1.1->yfinance) (1.14.0)
# Requirement already satisfied: webencodings in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.3.0->yfinance) (2.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.31->yfinance) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.31->yfinance) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.31->yfinance) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.31->yfinance) (2019.11.28)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# must re pip yfinance every time you run the notebook
# !pip install yfinance
import yfinance as yf
import pandas as pd

my_tickers = input('Input ticker\'s here:\n')

df = yf.download(
    tickers = my_tickers,
    period='7d', # valid intervals: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,msx
    interval='30m' # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
    )

ticker_list = my_tickers.split(', ')
ticker_list

data = yf.download(
    
    tickers= ticker_list,
    
    group_by= 'ticker',
    
    period='5y',
    
    interval='1d'

)


# count = 0
# list_of_dfs = []
# data = {'Ticker':[],
#     'Open (7 Days Ago)':[],
#     'Close (Yesterday)':[],
#     '7DayChange':[],
#     'Report Date':[]}
# df_out = pd.DataFrame(data)

# for aticker in ticker_list:
#     count = count + 1
#     astr = str(count)
#     adf = 'df'+astr
#     adf = yf.download(
#         tickers = aticker,
#         period='7d',
#         interval='30m'
#     )
#     close = adf.loc[adf.index.max()]['Close']
#     open = adf.loc[adf.index.min()]['Open']
#     diff = close - open

#     ticker = aticker
#     data = {
#         'Ticker':[ticker],
#         'Open (7 Days Ago)':[open],
#         'Close (Yesterday)':[close],
#         '7DayChange':[diff],
#         'Report Date':[end_date]}

#     new_row = pd.DataFrame(data)
#     df_out = pd.concat([df_out, new_row], ignore_index=True)
#     print(count)
#     # print("Ticker:",aticker, "\nMost recent stock price:",df.loc[df.index.max()]['Close'])
# print('Data:')
# df_out
# Out:
# Input ticker's here:
# AAPL, TSLA, AMZN, META
# [*********************100%%**********************]  4 of 4 completed
# [*********************100%%**********************]  4 of 4 completed

# %%
ticker_list
# Out:
# ['AAPL', 'TSLA', 'AMZN', 'META']

# %%
def curr_price(ticker, price_option):
    '''
    Function returns most recent close or open price of stock of interest.
    
    ticker = ticker you want to see
    price_option = close or open
    
    '''
    close = data[ticker].loc[data[ticker].index.max()][price_option]
    return close

# %%
curr_price('AAPL', 'Close')
# Out:
# 177.4499969482422

# %%
for t in ticker_list:
    print('Last closing price of',t,":",curr_price(t, 'Close'))
# Out:
# Last closing price of AAPL : 177.4499969482422
# Last closing price of TSLA : 232.9600067138672
# Last closing price of AMZN : 137.6699981689453
# Last closing price of META : 301.95001220703125

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (7.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets) (5.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets) (5.0.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets) (7.12.0)
# Requirement already satisfied: jupyter-client in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.3)
# Requirement already satisfied: appnope in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (46.0.0.post20200309)
# Requirement already satisfied: jedi>=0.10 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.14.1)
# Requirement already satisfied: decorator in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.4.1)
# Requirement already satisfied: pickleshare in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.3)
# Requirement already satisfied: pygments in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (2.5.2)
# Requirement already satisfied: backcall in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.1.0)
# Requirement already satisfied: pexpect in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: ipython-genutils in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.1)
# Requirement already satisfied: six in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets) (1.14.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.0.3)
# Requirement already satisfied: parso>=0.5.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.5.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.15.7)
# Requirement already satisfied: importlib-metadata in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (2.1.1)
# Requirement already satisfied: jinja2 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.1)
# Requirement already satisfied: pyzmq>=17 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (18.1.1)
# Requirement already satisfied: nbconvert in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.6.1)
# Requirement already satisfied: Send2Trash in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied: prometheus-client in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: wcwidth in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.1.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: bleach in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: testpath in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: defusedxml in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: webencodings in /Users/jakepulitzer/opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# visit URL below for more info on ipywidgets
# https://github.com/jupyter-widgets/ipywidgets/blob/689bc46a14e81c83c97ff8534b4eda6dfa46f574/docs/source/examples/Widget%20Basics.ipynb
import ipywidgets as widgets

# %%
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
display(w)
# Out:
# IntSlider(value=0)

# %%
out = widgets.Output(layout={'border': '1px solid black', 'width':'100%', 'height':'1000px'})
out
# Out:
# Output(layout=Layout(border='1px solid black', height='1000px', width='100%'))

# %%
with out:
    for t in ticker_list:
        print('Last closing price of',t,":",curr_price(t, 'Close'))

# %%
# Utils widgets
from ipywidgets import Button, Layout, jslink, IntText, IntSlider

def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))

from ipywidgets import AppLayout, Button, Layout

header_button = create_expanded_button('Header', 'success')
left_button = create_expanded_button('Left', 'info')
center_button = create_expanded_button('Center', 'warning')
right_button = create_expanded_button('Right', 'info')
footer_button = create_expanded_button('Footer', 'success')

# %%
AppLayout(header=header_button,
         left_sidebar=left_button,
         center=center_button,
         right_sidebar=right_button,
         footer=footer_button)
# Out:
# AppLayout(children=(Button(button_style='success', description='Header', layout=Layout(grid_area='header', hei…

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for t in ticker_list:
    sns.displot(data= data[t]['Close'], kde=True)
    plt.title("Stock: "+t)

# %%
data['META'].index
# Out:
# DatetimeIndex(['2018-08-16', '2018-08-17', '2018-08-20', '2018-08-21',
#                '2018-08-22', '2018-08-23', '2018-08-24', '2018-08-27',
#                '2018-08-28', '2018-08-29',
#                ...
#                '2023-08-02', '2023-08-03', '2023-08-04', '2023-08-07',
#                '2023-08-08', '2023-08-09', '2023-08-10', '2023-08-11',
#                '2023-08-14', '2023-08-15'],
#               dtype='datetime64[ns]', name='Date', length=1257, freq=None)

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(20,10))

for t in ticker_list:
    sns.lineplot(x=data[t].index, y=data[t]['Close'], data=data[t])
    plt.legend()
    plt.ylabel('Close Price')
    plt.xlabel('Date (Year), Past 5 Years')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
data
# Out:
#                   META                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (META, Open)       1257 non-null   float64
#  1   (META, High)       1257 non-null   float64
#  2   (META, Low)        1257 non-null   float64
#  3   (META, Close)      1257 non-null   float64
#  4   (META, Adj Close)  1257 non-null   float64
#  5   (META, Volume)     1257 non-null   int64
#  6   (AMZN, Open)       1257 non-null   float64
#  7   (AMZN, High)       1257 non-null   float64
#  8   (AMZN, Low)        1257 non-null   float64
#  9   (AMZN, Close)      1257 non-null   float64
#  10  (AMZN, Adj Close)  1257 non-null   float64
#  11  (AMZN, Volume)     1257 non-null   int64
#  12  (TSLA, Open)       1257 non-null   float64
#  13  (TSLA, High)       1257 non-null   float64
#  14  (TSLA, Low)        1257 non-null   float64
#  15  (TSLA, Close)      1257 non-null   float64
#  16  (TSLA, Adj Close)  1257 non-null   float64
#  17  (TSLA, Volume)     1257 non-null   int64
#  18  (AAPL, Open)       1257 non-null   float64
#  19  (AAPL, High)       1257 non-null   float64
#  20  (AAPL, Low)        1257 non-null   float64
#  21  (AAPL, Close)      1257 non-null   float64
#  22  (AAPL, Adj Close)  1257 non-null   float64
#  23  (AAPL, Volume)     1257 non-null   int64
# dtypes: float64(20), int64(4)
# memory usage: 277.8 KB

# %%
close_vals = pd.DataFrame({
    'META':data[('META', 'Close')],
    'TSLA':data[('TSLA', 'Close')],
    'AAPL':data[('AAPL', 'Close')],
    'AMZN':data[('AMZN', 'Close')]
})
close_vals.tail()
# Out:
#                   META        TSLA        AAPL        AMZN
# Date
# 2023-08-09  305.209991  242.190002  178.190002  137.850006
# 2023-08-10  305.739990  245.339996  177.970001  138.559998
# 2023-08-11  301.640015  242.649994  177.789993  138.410004
# 2023-08-14  306.190002  239.759995  179.460007  140.570007
# 2023-08-15  301.950012  232.960007  177.449997  137.669998

# %%
un_pivot = close_vals
un_pivot.reset_index(inplace=True)
un_pivot = pd.melt(close_vals,
                  id_vars = 'Date',
                  value_vars = ['META', 'TSLA', 'AAPL', 'AMZN'])

# %%
un_pivot
# Out:
#            Date variable       value
# 0    2018-08-16     META  174.699997
# 1    2018-08-17     META  173.800003
# 2    2018-08-20     META  172.500000
# 3    2018-08-21     META  172.619995
# 4    2018-08-22     META  173.639999
# ...         ...      ...         ...
# 5023 2023-08-09     AMZN  137.850006
# 5024 2023-08-10     AMZN  138.559998
# 5025 2023-08-11     AMZN  138.410004
# 5026 2023-08-14     AMZN  140.570007
# 5027 2023-08-15     AMZN  137.669998
#
# [5028 rows x 3 columns]

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(20,10))

sns.lineplot(x='Date', y='value', data=un_pivot, hue='variable')
plt.legend()
plt.ylabel('Close Price')
plt.xlabel('Date (Year), Past 5 Years')
# Out:
# Text(0.5, 0, 'Date (Year), Past 5 Years')

# %%
# delta = close_vals['META'].diff()
# up = delta.clip(lower=0)
# down = -1*delta.clip(upper=0)
# ema_up = up.ewm(com=13, adjust=False).mean()
# ema_down = down.ewm(com=13, adjust=False).mean()
# rs = ema_up/ema_down
# close_vals['rsi meta'] = 100 - (100/(1+rs))

# %%
def rsi(df, ticker):
    delta = df[ticker].diff()
    period=14
    gain = delta.where(delta>0, 0)
    loss = -delta.where(delta<0,0)
    avg_gain = gain.rolling(period).mean()
    avg_loss = loss.rolling(period).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
#     down = -1*delta.clip(upper=0)
#     ema_up = up.ewm(com=13, adjust=False).mean()
#     ema_down = down.ewm(com=13, adjust=False).mean()
#     rs = ema_up/ema_down
    new_field_name = 'rsi_'+ticker
    df[new_field_name]= 100 - (100 /(1+rs) )
    return df

# %%
close_vals
# Out:
#            Date        META        TSLA        AAPL        AMZN
# 0    2018-08-16  174.699997   22.363333   53.330002   94.325996
# 1    2018-08-17  173.800003   20.366667   54.395000   94.111000
# 2    2018-08-20  172.500000   20.562668   53.865002   93.835503
# 3    2018-08-21  172.619995   21.459999   53.759998   94.170998
# 4    2018-08-22  173.639999   21.442667   53.762501   95.245003
# ...         ...         ...         ...         ...         ...
# 1252 2023-08-09  305.209991  242.190002  178.190002  137.850006
# 1253 2023-08-10  305.739990  245.339996  177.970001  138.559998
# 1254 2023-08-11  301.640015  242.649994  177.789993  138.410004
# 1255 2023-08-14  306.190002  239.759995  179.460007  140.570007
# 1256 2023-08-15  301.950012  232.960007  177.449997  137.669998
#
# [1257 rows x 5 columns]

# %%
for t in ticker_list:
    rsi(close_vals, t)
close_vals.tail()
# Out:
#            Date        META        TSLA        AAPL        AMZN   rsi_AAPL  \
# 1252 2023-08-09  305.209991  242.190002  178.190002  137.850006  23.715673
# 1253 2023-08-10  305.739990  245.339996  177.970001  138.559998  24.553715
# 1254 2023-08-11  301.640015  242.649994  177.789993  138.410004  22.110345
# 1255 2023-08-14  306.190002  239.759995  179.460007  140.570007  24.366432
# 1256 2023-08-15  301.950012  232.960007  177.449997  137.669998  20.347837
#
#        rsi_TSLA   rsi_AMZN   rsi_META
# 1252  35.746736  62.355160  51.583659
# 1253  39.934177  63.128840  57.435219
# 1254  30.163728  65.229808  56.376373
# 1255  30.572463  67.136026  57.294007
# 1256  28.064283  63.484436  52.099906

# %%
close_vals.set_index('Date', inplace=True);close_vals.head()
# Out:
#                   META       TSLA       AAPL       AMZN  rsi_AAPL  rsi_TSLA  \
# Date
# 2018-08-16  174.699997  22.363333  53.330002  94.325996       NaN       NaN
# 2018-08-17  173.800003  20.366667  54.395000  94.111000       NaN       NaN
# 2018-08-20  172.500000  20.562668  53.865002  93.835503       NaN       NaN
# 2018-08-21  172.619995  21.459999  53.759998  94.170998       NaN       NaN
# 2018-08-22  173.639999  21.442667  53.762501  95.245003       NaN       NaN
#
#             rsi_AMZN  rsi_META
# Date
# 2018-08-16       NaN       NaN
# 2018-08-17       NaN       NaN
# 2018-08-20       NaN       NaN
# 2018-08-21       NaN       NaN
# 2018-08-22       NaN       NaN

# %%
for t in ticker_list:
    print(t)
    close_vals2 = close_vals.iloc[14:]
    fig, (ax1, ax2) = plt.subplots(2)
    ax1.get_xaxis().set_visible(False)
    fig.suptitle(t)
    close_vals2[t].plot(ax=ax1)
    ax1.set_ylabel('Price ($)')
    rsi_t = 'rsi_'+t
    close_vals2[rsi_t].plot(ax=ax2)
    ax2.set_ylim(0, 100)
    ax2.axhline(30, color='r', linestyle='--')
    ax2.axhline(80, color='g', linestyle='--')
    ax2.set_ylabel('RSI')
    fig.set_size_inches(15, 10)
    plt.show()
# Out:
# AAPL
# TSLA
# AMZN
# META
